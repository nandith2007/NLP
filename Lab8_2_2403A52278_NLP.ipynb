# %% [markdown]
# <a href="https://colab.research.google.com/github/nandith2007/NLP/blob/main/Lab8_2_2403A52278_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Corpus**

# %%
D1: "The weather today is sunny and pleasant for outdoor activities."
D2: "Machine learning helps computers learn patterns from data."
D3: "The football match last night was exciting and full of surprises."
D4: "Online shopping platforms offer discounts during festive seasons."
D5: "Cyber security is important to protect systems from attacks."
D6: "Students are preparing for exams using online study materials."
D7: "Artificial intelligence is transforming healthcare and education."
D8: "Social media influences public opinion and daily communication."
D9: "Data science combines statistics, programming, and domain knowledge."
D10: "Traveling to new places helps people experience different cultures."

# %% [markdown]
# # **Uni Gram Counts**

# %%
import collections
D1: "The weather today is sunny and pleasant for outdoor activities."
D2: "Machine learning helps computers learn patterns from data."
D3: "The football match last night was exciting and full of surprises."
D4: "Online shopping platforms offer discounts during festive seasons."
D5: "Cyber security is important to protect systems from attacks."
D6: "Students are preparing for exams using online study materials."
D7: "Artificial intelligence is transforming healthcare and education."
D8: "Social media influences public opinion and daily communication."
D9: "Data science combines statistics, programming, and domain knowledge."
D10: "Traveling to new places helps people experience different cultures."

D1_content="The weather today is sunny and pleasant for outdoor activities."
D2_content="Machine learning helps computers learn patterns from data."
D3_content="The football match last night was exciting and full of surprises."
D4_content="Online shopping platforms offer discounts during festive seasons."
D5_content="Cyber security is important to protect systems from attacks."
D6_content="Students are preparing for exams using online study materials."
D7_content="Artificial intelligence is transforming healthcare and education."
D8_content="Social media influences public opinion and daily communication."
D9_content="Data science combines statistics, programming, and domain knowledge."
D10_content="Traveling to new places helps people experience different cultures."

combined_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content}"

words = combined_text.lower().split()

unigram_counts = collections.Counter(words)

print("Unigram Counts:")
for word, count in unigram_counts.most_common():
    print(f"{word}: {count}")
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# Unigram Counts:
# and: 5
# is: 3
# the: 2
# for: 2
# helps: 2
# from: 2
# online: 2
# to: 2
# weather: 1
# today: 1
# sunny: 1
# pleasant: 1
# outdoor: 1
# activities.: 1
# machine: 1
# learning: 1
# computers: 1
# learn: 1
# patterns: 1
# data.: 1
# football: 1
# match: 1
# last: 1
# night: 1
# was: 1
# exciting: 1
# full: 1
# of: 1
# surprises.: 1
# shopping: 1
# platforms: 1
# offer: 1
# discounts: 1
# during: 1
# festive: 1
# seasons.: 1
# cyber: 1
# security: 1
# important: 1
# protect: 1
# systems: 1
# attacks.: 1
# students: 1
# are: 1
# preparing: 1
# exams: 1
# using: 1
# study: 1
# materials.: 1
# artificial: 1
# intelligence: 1
# transforming: 1
# healthcare: 1
# education.: 1
# social: 1
# media: 1
# influences: 1
# public: 1
# opinion: 1
# daily: 1
# communication.: 1
# data: 1
# science: 1
# combines: 1
# statistics,: 1
# programming,: 1
# domain: 1
# knowledge.: 1
# traveling: 1
# new: 1
# places: 1
# people: 1
# experience: 1
# different: 1
# cultures.: 1
# Vocabulary Size= 75

# %% [markdown]
# # **Bi-Gram Counts**

# %%
import collections


combined_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content}"
words = combined_text.lower().split()

bigrams = []
for i in range(len(words) - 1):
    bigrams.append((words[i], words[i+1]))

bigram_counts = collections.Counter(bigrams)

print("\nBigram Counts:")
for bigram, count in bigram_counts.most_common():
    print(f"{bigram[0]} {bigram[1]}: {count}")
# Out:
# Bigram Counts:
# the weather: 1
# weather today: 1
# today is: 1
# is sunny: 1
# sunny and: 1
# and pleasant: 1
# pleasant for: 1
# for outdoor: 1
# outdoor activities.: 1
# activities. machine: 1
# machine learning: 1
# learning helps: 1
# helps computers: 1
# computers learn: 1
# learn patterns: 1
# patterns from: 1
# from data.: 1
# data. the: 1
# the football: 1
# football match: 1
# match last: 1
# last night: 1
# night was: 1
# was exciting: 1
# exciting and: 1
# and full: 1
# full of: 1
# of surprises.: 1
# surprises. online: 1
# online shopping: 1
# shopping platforms: 1
# platforms offer: 1
# offer discounts: 1
# discounts during: 1
# during festive: 1
# festive seasons.: 1
# seasons. cyber: 1
# cyber security: 1
# security is: 1
# is important: 1
# important to: 1
# to protect: 1
# protect systems: 1
# systems from: 1
# from attacks.: 1
# attacks. students: 1
# students are: 1
# are preparing: 1
# preparing for: 1
# for exams: 1
# exams using: 1
# using online: 1
# online study: 1
# study materials.: 1
# materials. artificial: 1
# artificial intelligence: 1
# intelligence is: 1
# is transforming: 1
# transforming healthcare: 1
# healthcare and: 1
# and education.: 1
# education. social: 1
# social media: 1
# media influences: 1
# influences public: 1
# public opinion: 1
# opinion and: 1
# and daily: 1
# daily communication.: 1
# communication. data: 1
# data science: 1
# science combines: 1
# combines statistics,: 1
# statistics, programming,: 1
# programming, and: 1
# and domain: 1
# domain knowledge.: 1
# knowledge. traveling: 1
# traveling to: 1
# to new: 1
# new places: 1
# places helps: 1
# helps people: 1
# people experience: 1
# experience different: 1
# different cultures.: 1

# %% [markdown]
# # **Tri-Gram Counts**

# %%
import collections

combined_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content}"
words = combined_text.lower().split()

Trigrams = []
for i in range(len(words) - 2):
    Trigrams.append((words[i], words[i+1], words[i+2]))

Trigrams_counts = collections.Counter(Trigrams)

print("\nTrigrams Counts:")
for Trigrams, count in Trigrams_counts.most_common():
    print(f"{Trigrams[0]} {Trigrams[1]} {Trigrams[2]}: {count}")
# Out:
# Trigrams Counts:
# the weather today: 1
# weather today is: 1
# today is sunny: 1
# is sunny and: 1
# sunny and pleasant: 1
# and pleasant for: 1
# pleasant for outdoor: 1
# for outdoor activities.: 1
# outdoor activities. machine: 1
# activities. machine learning: 1
# machine learning helps: 1
# learning helps computers: 1
# helps computers learn: 1
# computers learn patterns: 1
# learn patterns from: 1
# patterns from data.: 1
# from data. the: 1
# data. the football: 1
# the football match: 1
# football match last: 1
# match last night: 1
# last night was: 1
# night was exciting: 1
# was exciting and: 1
# exciting and full: 1
# and full of: 1
# full of surprises.: 1
# of surprises. online: 1
# surprises. online shopping: 1
# online shopping platforms: 1
# shopping platforms offer: 1
# platforms offer discounts: 1
# offer discounts during: 1
# discounts during festive: 1
# during festive seasons.: 1
# festive seasons. cyber: 1
# seasons. cyber security: 1
# cyber security is: 1
# security is important: 1
# is important to: 1
# important to protect: 1
# to protect systems: 1
# protect systems from: 1
# systems from attacks.: 1
# from attacks. students: 1
# attacks. students are: 1
# students are preparing: 1
# are preparing for: 1
# preparing for exams: 1
# for exams using: 1
# exams using online: 1
# using online study: 1
# online study materials.: 1
# study materials. artificial: 1
# materials. artificial intelligence: 1
# artificial intelligence is: 1
# intelligence is transforming: 1
# is transforming healthcare: 1
# transforming healthcare and: 1
# healthcare and education.: 1
# and education. social: 1
# education. social media: 1
# social media influences: 1
# media influences public: 1
# influences public opinion: 1
# public opinion and: 1
# opinion and daily: 1
# and daily communication.: 1
# daily communication. data: 1
# communication. data science: 1
# data science combines: 1
# science combines statistics,: 1
# combines statistics, programming,: 1
# statistics, programming, and: 1
# programming, and domain: 1
# and domain knowledge.: 1
# domain knowledge. traveling: 1
# knowledge. traveling to: 1
# traveling to new: 1
# to new places: 1
# new places helps: 1
# places helps people: 1
# helps people experience: 1
# people experience different: 1
# experience different cultures.: 1

# %% [markdown]
# Next Word Prediction Using Bi-Gram Counts**

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I am"
next_word1 = predict_next_word_bigram(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_bigram(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "professor I"
next_word3 = predict_next_word_bigram(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# Given sequence: 'I am', predicted next word: 'No bigram found starting with 'am'.'
# Given sequence: 'I did my', predicted next word: 'No bigram found starting with 'my'.'
# Given sequence: 'professor I', predicted next word: 'No bigram found starting with 'i'.'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %% [markdown]
# # **Deployment of Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textstudents are
# probability of  preparing is  1.0
# Given sequence: 'students are', predicted next word: 'preparing'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts**

# %%
def predict_next_word_trigram(word_sequence, Trigrams_counts, bigram_counts):
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am working"
next_word1 = predict_next_word_trigram(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_trigram(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# Given sequence: 'I am working', predicted next word: 'No trigram found starting with 'am working'.'
# Given sequence: 'I did my', predicted next word: 'No trigram found starting with 'did my'.'

# %% [markdown]
# # **Deployment of Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textthe weather
# probability of  today is  1.0
# Given sequence: 'the weather', predicted next word: 'today'

# %% [markdown]
# # **Next Word Prediction Using Bi-Gram Counts with Laplace Smoothening**

# %%
def predict_next_word_bigram_Laplace(word_sequence, bigram_counts, unigram_counts):
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+1) / (last_word_unigram_count+V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am"
next_word1 = predict_next_word_bigram_Laplace(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_bigram_Laplace(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "professor I"
next_word3 = predict_next_word_bigram_Laplace(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram_Laplace(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# Given sequence: 'I am', predicted next word: 'No bigram found starting with 'am'.'
# Given sequence: 'I did my', predicted next word: 'No bigram found starting with 'my'.'
# Given sequence: 'professor I', predicted next word: 'No bigram found starting with 'i'.'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %% [markdown]
# # **Deployment of Laplace Smoothening based Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_Laplace(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textdata science
# probability of combines is  0.02631578947368421
# Given sequence: 'data science', predicted next word: 'combines'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts based on laplace smoothening**

# %%
def predict_next_word_trigram_Laplace(word_sequence, Trigrams_counts, bigram_counts):
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+1) / (last_two_words_bigram_count+V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am working"
next_word1 = predict_next_word_trigram_Laplace(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_trigram_Laplace(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# Given sequence: 'I am working', predicted next word: 'No trigram found starting with 'am working'.'
# Given sequence: 'I did my', predicted next word: 'No trigram found starting with 'did my'.'

# %% [markdown]
# # **Deployment of Laplace Smoothening based Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_Laplace(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textcyber security
# probability of  is is  0.02631578947368421
# Given sequence: 'cyber security', predicted next word: 'is'

# %% [markdown]
# # **Next Word Prediction Using Bi-Gram Counts with Add - K Smoothening**

# %%
def predict_next_word_bigram_K(word_sequence, bigram_counts, unigram_counts, K): #K=0.5-0.01
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+K) / (last_word_unigram_count+K*V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am"
next_word1 = predict_next_word_bigram_K(sequence1, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_bigram_K(sequence2, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "professor I"
next_word3 = predict_next_word_bigram_K(sequence3, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram_K(sequence4, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# Given sequence: 'I am', predicted next word: 'No bigram found starting with 'am'.'
# Given sequence: 'I did my', predicted next word: 'No bigram found starting with 'my'.'
# Given sequence: 'professor I', predicted next word: 'No bigram found starting with 'i'.'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %% [markdown]
# # **Deployment of Add-K Smoothening based Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_K(ip_text, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textthe football
# probability of match is  0.03896103896103896
# Given sequence: 'the football', predicted next word: 'match'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts with Add - K Smoothening**

# %%
def predict_next_word_trigram_K(word_sequence, Trigrams_counts, bigram_counts,K): #K=0.5-0.01
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+K) / (last_two_words_bigram_count+K*V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Example usage:
# Ensure bigram_counts, unigram_counts, and Trigrams_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "I am working"
next_word1 = predict_next_word_trigram_K(sequence1, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_trigram_K(sequence2, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# Given sequence: 'I am working', predicted next word: 'No trigram found starting with 'am working'.'
# Given sequence: 'I did my', predicted next word: 'No trigram found starting with 'did my'.'

# %% [markdown]
# # **Deployment of Add-K Smoothening based Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_K(ip_text, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textmachine learning
# probability of  helps is  0.03896103896103896
# Given sequence: 'machine learning', predicted next word: 'helps'

# %% [markdown]
# # **Thank You**
